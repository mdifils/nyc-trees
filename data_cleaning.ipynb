# %%
import numpy as  np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Let's import data from .csv file and look how does it look alike.

# %%
df = pd.read_csv("uncleaned_data.csv")
print("Original size: ", df.shape)
df.head().T
# Out:
# Original size:  (110000, 42)
#                                                         0  \
# created_at                                     08/27/2015
# tree_id                                            180683
# block_id                                           348711
# the_geom    POINT (-73.84421521958048 40.723091773924274)
# tree_dbh                                                3
# stump_diam                                              0
# curb_loc                                           OnCurb
# status                                              Alive
# health                                               Fair
# spc_latin                                     Acer rubrum
# spc_common                                      red maple
# steward                                              None
# guards                                               None
# sidewalk                                         NoDamage
# user_type                                TreesCount Staff
# problems                                             None
# root_stone                                             No
# root_grate                                             No
# root_other                                             No
# trnk_wire                                              No
# trnk_light                                             No
# trnk_other                                             No
# brnch_ligh                                             No
# brnch_shoe                                             No
# brnch_othe                                             No
# address                                 108-005 70 AVENUE
# zipcode                                             11375
# zip_city                                     Forest Hills
# cb_num                                                406
# borocode                                                4
# boroname                                           Queens
# cncldist                                               29
# st_assem                                               28
# st_senate                                              16
# nta                                                  QN17
# nta_name                                     Forest Hills
# boro_ct                                           4073900
# state                                            New York
# latitude                                        40.723092
# longitude                                      -73.844215
# x_sp                                        1027431.14821
# y_sp                                        202756.768749
#
#                                                        1  \
# created_at                                    09/03/2015
# tree_id                                           200540
# block_id                                          315986
# the_geom    POINT (-73.81867945834878 40.79411066708779)
# tree_dbh                                              21
# stump_diam                                             0
# curb_loc                                          OnCurb
# status                                             Alive
# health                                              Fair
# spc_latin                              Quercus palustris
# spc_common                                       pin oak
# steward                                             None
# guards                                              None
# sidewalk                                          Damage
# user_type                               TreesCount Staff
# problems                                          Stones
# root_stone                                           Yes
# root_grate                                            No
# root_other                                            No
# trnk_wire                                             No
# trnk_light                                            No
# trnk_other                                            No
# brnch_ligh                                            No
# brnch_shoe                                            No
# brnch_othe                                            No
# address                                 147-074 7 AVENUE
# zipcode                                            11357
# zip_city                                      Whitestone
# cb_num                                               407
# borocode                                               4
# boroname                                          Queens
# cncldist                                              19
# st_assem                                              27
# st_senate                                             11
# nta                                                 QN49
# nta_name                                      Whitestone
# boro_ct                                          4097300
# state                                           New York
# latitude                                       40.794111
# longitude                                     -73.818679
# x_sp                                       1034455.70109
# y_sp                                       228644.837379
#
#                                                         2  \
# created_at                                     09/05/2015
# tree_id                                            204026
# block_id                                           218365
# the_geom    POINT (-73.93660770459083 40.717580740099116)
# tree_dbh                                                3
# stump_diam                                              0
# curb_loc                                           OnCurb
# status                                              Alive
# health                                               Good
# spc_latin              Gleditsia triacanthos var. inermis
# spc_common                                    honeylocust
# steward                                              1or2
# guards                                               None
# sidewalk                                           Damage
# user_type                                       Volunteer
# problems                                             None
# root_stone                                             No
# root_grate                                             No
# root_other                                             No
# trnk_wire                                              No
# trnk_light                                             No
# trnk_other                                             No
# brnch_ligh                                             No
# brnch_shoe                                             No
# brnch_othe                                             No
# address                                 390 MORGAN AVENUE
# zipcode                                             11211
# zip_city                                         Brooklyn
# cb_num                                                301
# borocode                                                3
# boroname                                         Brooklyn
# cncldist                                               34
# st_assem                                               50
# st_senate                                              18
# nta                                                  BK90
# nta_name                                East Williamsburg
# boro_ct                                           3044900
# state                                            New York
# latitude                                        40.717581
# longitude                                      -73.936608
# x_sp                                        1001822.83131
# y_sp                                        200716.891267
#
#                                                         3  \
# created_at                                     09/05/2015
# tree_id                                            204337
# block_id                                           217969
# the_geom    POINT (-73.93445615919741 40.713537494833226)
# tree_dbh                                               10
# stump_diam                                              0
# curb_loc                                           OnCurb
# status                                              Alive
# health                                               Good
# spc_latin              Gleditsia triacanthos var. inermis
# spc_common                                    honeylocust
# steward                                              None
# guards                                               None
# sidewalk                                           Damage
# user_type                                       Volunteer
# problems                                           Stones
# root_stone                                            Yes
# root_grate                                             No
# root_other                                             No
# trnk_wire                                              No
# trnk_light                                             No
# trnk_other                                             No
# brnch_ligh                                             No
# brnch_shoe                                             No
# brnch_othe                                             No
# address                                 1027 GRAND STREET
# zipcode                                             11211
# zip_city                                         Brooklyn
# cb_num                                                301
# borocode                                                3
# boroname                                         Brooklyn
# cncldist                                               34
# st_assem                                               53
# st_senate                                              18
# nta                                                  BK90
# nta_name                                East Williamsburg
# boro_ct                                           3044900
# state                                            New York
# latitude                                        40.713537
# longitude                                      -73.934456
# x_sp                                        1002420.35833
# y_sp                                        199244.253136
#
#                                                        4
# created_at                                    08/30/2015
# tree_id                                           189565
# block_id                                          223043
# the_geom    POINT (-73.97597938483258 40.66677775537875)
# tree_dbh                                              21
# stump_diam                                             0
# curb_loc                                          OnCurb
# status                                             Alive
# health                                              Good
# spc_latin                                Tilia americana
# spc_common                               American linden
# steward                                             None
# guards                                              None
# sidewalk                                          Damage
# user_type                                      Volunteer
# problems                                          Stones
# root_stone                                           Yes
# root_grate                                            No
# root_other                                            No
# trnk_wire                                             No
# trnk_light                                            No
# trnk_other                                            No
# brnch_ligh                                            No
# brnch_shoe                                            No
# brnch_othe                                            No
# address                                     603 6 STREET
# zipcode                                            11215
# zip_city                                        Brooklyn
# cb_num                                               306
# borocode                                               3
# boroname                                        Brooklyn
# cncldist                                              39
# st_assem                                              44
# st_senate                                             21
# nta                                                 BK37
# nta_name                              Park Slope-Gowanus
# boro_ct                                          3016500
# state                                           New York
# latitude                                       40.666778
# longitude                                     -73.975979
# x_sp                                       990913.775046
# y_sp                                       182202.425999

# %% [markdown]
# ### Dopping columns
# **the_geom:** this column is summary of latitude and longitude columns. So we can drop it without loosing data.
#
# **spc_latin:** this is a scientific name of a tree, we can keep the common name.
#
# **block_id:** does not bring relevant information for the AI model
#
# **address, city_zip, borocode, boroname:** are all information about the location and we already have latitude, longitude and zip code.

# %%
df.drop(['the_geom','spc_latin','block_id','address','zip_city','borocode','boroname'], axis=1, inplace=True)
df.head().T
# Out:
#                            0                 1                  2  \
# created_at        08/27/2015        09/03/2015         09/05/2015
# tree_id               180683            200540             204026
# tree_dbh                   3                21                  3
# stump_diam                 0                 0                  0
# curb_loc              OnCurb            OnCurb             OnCurb
# status                 Alive             Alive              Alive
# health                  Fair              Fair               Good
# spc_common         red maple           pin oak        honeylocust
# steward                 None              None               1or2
# guards                  None              None               None
# sidewalk            NoDamage            Damage             Damage
# user_type   TreesCount Staff  TreesCount Staff          Volunteer
# problems                None            Stones               None
# root_stone                No               Yes                 No
# root_grate                No                No                 No
# root_other                No                No                 No
# trnk_wire                 No                No                 No
# trnk_light                No                No                 No
# trnk_other                No                No                 No
# brnch_ligh                No                No                 No
# brnch_shoe                No                No                 No
# brnch_othe                No                No                 No
# zipcode                11375             11357              11211
# cb_num                   406               407                301
# cncldist                  29                19                 34
# st_assem                  28                27                 50
# st_senate                 16                11                 18
# nta                     QN17              QN49               BK90
# nta_name        Forest Hills        Whitestone  East Williamsburg
# boro_ct              4073900           4097300            3044900
# state               New York          New York           New York
# latitude           40.723092         40.794111          40.717581
# longitude         -73.844215        -73.818679         -73.936608
# x_sp           1027431.14821     1034455.70109      1001822.83131
# y_sp           202756.768749     228644.837379      200716.891267
#
#                             3                   4
# created_at         09/05/2015          08/30/2015
# tree_id                204337              189565
# tree_dbh                   10                  21
# stump_diam                  0                   0
# curb_loc               OnCurb              OnCurb
# status                  Alive               Alive
# health                   Good                Good
# spc_common        honeylocust     American linden
# steward                  None                None
# guards                   None                None
# sidewalk               Damage              Damage
# user_type           Volunteer           Volunteer
# problems               Stones              Stones
# root_stone                Yes                 Yes
# root_grate                 No                  No
# root_other                 No                  No
# trnk_wire                  No                  No
# trnk_light                 No                  No
# trnk_other                 No                  No
# brnch_ligh                 No                  No
# brnch_shoe                 No                  No
# brnch_othe                 No                  No
# zipcode                 11211               11215
# cb_num                    301                 306
# cncldist                   34                  39
# st_assem                   53                  44
# st_senate                  18                  21
# nta                      BK90                BK37
# nta_name    East Williamsburg  Park Slope-Gowanus
# boro_ct               3044900             3016500
# state                New York            New York
# latitude            40.713537           40.666778
# longitude          -73.934456          -73.975979
# x_sp            1002420.35833       990913.775046
# y_sp            199244.253136       182202.425999

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110000 entries, 0 to 109999
# Data columns (total 35 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   created_at  110000 non-null  object
#  1   tree_id     110000 non-null  int64
#  2   tree_dbh    110000 non-null  int64
#  3   stump_diam  110000 non-null  int64
#  4   curb_loc    110000 non-null  object
#  5   status      110000 non-null  object
#  6   health      104508 non-null  object
#  7   spc_common  104509 non-null  object
#  8   steward     104509 non-null  object
#  9   guards      104509 non-null  object
#  10  sidewalk    104509 non-null  object
#  11  user_type   110000 non-null  object
#  12  problems    104509 non-null  object
#  13  root_stone  110000 non-null  object
#  14  root_grate  110000 non-null  object
#  15  root_other  110000 non-null  object
#  16  trnk_wire   110000 non-null  object
#  17  trnk_light  110000 non-null  object
#  18  trnk_other  110000 non-null  object
#  19  brnch_ligh  110000 non-null  object
#  20  brnch_shoe  110000 non-null  object
#  21  brnch_othe  110000 non-null  object
#  22  zipcode     110000 non-null  int64
#  23  cb_num      110000 non-null  int64
#  24  cncldist    110000 non-null  int64
#  25  st_assem    110000 non-null  int64
#  26  st_senate   110000 non-null  int64
#  27  nta         110000 non-null  object
#  28  nta_name    110000 non-null  object
#  29  boro_ct     110000 non-null  int64
#  30  state       110000 non-null  object
#  31  latitude    110000 non-null  float64
#  32  longitude   110000 non-null  float64
#  33  x_sp        110000 non-null  float64
#  34  y_sp        110000 non-null  float64
# dtypes: float64(4), int64(9), object(22)
# memory usage: 29.4+ MB

# %%
df.describe().T
# Out:
#                count          mean           std           min           25%  \
# tree_id     110000.0  2.387664e+05  4.517995e+04  7.000000e+00  2.110788e+05
# tree_dbh    110000.0  1.126813e+01  8.593050e+00  0.000000e+00  5.000000e+00
# stump_diam  110000.0  4.671727e-01  3.424926e+00  0.000000e+00  0.000000e+00
# zipcode     110000.0  1.081924e+04  8.261737e+02  8.300000e+01  1.030900e+04
# cb_num      110000.0  3.163913e+02  1.264305e+02  1.010000e+02  2.100000e+02
# cncldist    110000.0  2.751890e+01  1.531759e+01  1.000000e+00  1.400000e+01
# st_assem    110000.0  5.253114e+01  1.837053e+01  2.300000e+01  3.600000e+01
# st_senate   110000.0  2.146288e+01  7.439490e+00  1.000000e+01  1.500000e+01
# boro_ct     110000.0  3.130955e+06  1.284663e+06  1.000201e+06  2.028800e+06
# latitude    110000.0  4.071018e+01  9.028271e-02  4.049847e+01  4.063451e+01
# longitude   110000.0 -7.392906e+01  1.168818e-01 -7.425439e+01 -7.397793e+01
# x_sp        110000.0  1.003892e+06  3.242028e+04  9.135095e+05  9.903679e+05
# y_sp        110000.0  1.980447e+05  3.289187e+04  1.209738e+05  1.704531e+05
#
#                      50%           75%           max
# tree_id     2.407725e+05  2.720622e+05  3.786080e+05
# tree_dbh    1.000000e+01  1.600000e+01  4.250000e+02
# stump_diam  0.000000e+00  0.000000e+00  1.400000e+02
# zipcode     1.120700e+04  1.135500e+04  1.169700e+04
# cb_num      3.140000e+02  4.110000e+02  5.030000e+02
# cncldist    2.600000e+01  4.000000e+01  5.100000e+01
# st_assem    5.200000e+01  6.700000e+01  8.700000e+01
# st_senate   2.200000e+01  2.700000e+01  3.600000e+01
# boro_ct     3.059402e+06  4.080302e+06  5.031902e+06
# latitude    4.072304e+01  4.077080e+01  4.091281e+01
# longitude  -7.393917e+01 -7.385076e+01 -7.370049e+01
# x_sp        1.001101e+06  1.025575e+06  1.067248e+06
# y_sp        2.027362e+05  2.201115e+05  2.718534e+05

# %%
# checking duplicated rows
df.duplicated().any()
# Out:
# False

# %% [markdown]
# No duplicated rows

# %%
# Percentage of missing values in every column
df.isna().sum()*100/len(df)
# Out:
# created_at    0.000000
# tree_id       0.000000
# tree_dbh      0.000000
# stump_diam    0.000000
# curb_loc      0.000000
# status        0.000000
# health        4.992727
# spc_common    4.991818
# steward       4.991818
# guards        4.991818
# sidewalk      4.991818
# user_type     0.000000
# problems      4.991818
# root_stone    0.000000
# root_grate    0.000000
# root_other    0.000000
# trnk_wire     0.000000
# trnk_light    0.000000
# trnk_other    0.000000
# brnch_ligh    0.000000
# brnch_shoe    0.000000
# brnch_othe    0.000000
# zipcode       0.000000
# cb_num        0.000000
# cncldist      0.000000
# st_assem      0.000000
# st_senate     0.000000
# nta           0.000000
# nta_name      0.000000
# boro_ct       0.000000
# state         0.000000
# latitude      0.000000
# longitude     0.000000
# x_sp          0.000000
# y_sp          0.000000
# dtype: float64

# %% [markdown]
# Only six columns with less than 5% missing values. It's okay

# %%
df.to_csv('cleaned_data.csv', encoding='utf-8', index=False)
